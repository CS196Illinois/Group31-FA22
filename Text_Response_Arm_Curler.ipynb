# %%
#pseudocode for text response 
#currently just printing to the screen, but in the future 
#it would probably be on the side of video on the website

#potential website view of where the text would go in future

# %% [markdown]
# ![Untitled drawing.png](data:image/png;base64,...)

# %%
#import random

# %%
message = "" #what gets printed out

# %%
#returning encouragement when they do the arm curl right 
"""
if counter++ (angle < 30 and stage == "down") :
  x = random.randint(1,3)
  if x == 1 :
    message = "Good job!"
  if x == 2 :
    message = "Amazing form!" 
  if x == 3 :
    message "Keep going, you're doing great!"
"""

# %%
#returning encouragement whent they do the arm curl wrong 
""" 
  countwrong = 0; #if someone does it wrong 5 times in a row, return different message
  if angle > 30 and angle < 160 and stage == "down" :
    countwrong++
    if countwrong % 5 == 0 :
      message = "You can do this! You've got it!"
    else : 
      message = "Try to bend your arm more"
"""
# Out:
# ' \n  countwrong = 0; #if someone does it wrong 5 times in a row, return different message\n  if angle > 30 and angle < 160 and stage == "down" :\n    countwrong++\n    if countwrong % 5 == 0 :\n      message = "You can do this! You\'ve got it!"\n    else : \n      message = "Try to bend your arm more"\n'

# %%
#potential addition: user inputs how many reps they want to do, 
#get a special message at end
#then that's when the workout ends and back to home screen

# %%
#rep = reps set by user 
""" 
if counter++ (angle < 30 and stage == "down") :
  x = random.randint(1,3)
  if counter == rep :
    message = "Great workout! You did amazing!" #this one potentially covers the screen?? 
    x = 0 
  if x == 1 :
    message = "Good job!"
  if x == 2 :
    message = "Amazing form!" 
  if x == 3 :
    message = "Keep going, you're doing great!"


"""
